# %%
# %%
# Python standard library
import math
import random
from itertools import product

# custom utils
from utils import display_maze
from examples.dense_maze_4x3 import maze

# %%
def full_maze(width, height):
    vertices = set(product(range(width), range(height)))
    edges = {}
    weights = {}
    return (vertices, egdes, weights)

def distance(x,y):
        return abs(y[0]-x[0]) + abs(y[1]-x[1])

def empty_maze(width, height):
    vertices = set(product(range(width), range(height)))
    E = product(vertices, vertices)
    edges = set((x,y) for (x,y) in E if distance(x,y) == 1)
    weights = {}

    return (vertices, edges, weights)

display_maze(empty_maze(10,10))
